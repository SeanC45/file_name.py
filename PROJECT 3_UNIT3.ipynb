# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np
import pandas as pd
df = pd.read_csv(r'G:\NYPD_Arrest_Data__Year_to_Date_.csv')
print(df.columns)
# Out:
# Index(['ARREST_KEY', 'ARREST_DATE', 'PD_CD', 'PD_DESC', 'KY_CD', 'OFNS_DESC',
#        'LAW_CODE', 'LAW_CAT_CD', 'ARREST_BORO', 'ARREST_PRECINCT',
#        'JURISDICTION_CODE', 'AGE_GROUP', 'PERP_SEX', 'PERP_RACE', 'X_COORD_CD',
#        'Y_COORD_CD', 'Latitude', 'Longitude', 'New Georeferenced Column'],
#       dtype='object')

# %%
#ALL Data Fields. 
df.head()
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD      PD_DESC  KY_CD   OFNS_DESC    LAW_CODE  \
# 0   238013474  12/18/2021  157.0       RAPE 1  104.0        RAPE  PL 1303501
# 1   236943583  11/25/2021  263.0  ARSON 2,3,4  114.0       ARSON  PL 1501500
# 2   234938876  10/14/2021  594.0  OBSCENITY 1  116.0  SEX CRIMES  PL 2631100
# 3   234788259  10/11/2021  263.0  ARSON 2,3,4  114.0       ARSON  PL 1501001
# 4   234188790   9/28/2021  578.0          NaN    NaN         NaN  PL 2223001
#
#   LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP  \
# 0          F           Q              105                 97     18-24
# 1          F           K               69                 71     25-44
# 2          F           K               61                  0     25-44
# 3          F           B               42                 71     18-24
# 4          M           B               44                  0     25-44
#
#   PERP_SEX PERP_RACE  X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# ...

# %%
#Removal of all Data not relevant
df.drop(['Latitude', 'Longitude', 'ARREST_KEY', 'New Georeferenced Column','X_COORD_CD', 'Y_COORD_CD', 'JURISDICTION_CODE', 'LAW_CODE', 'KY_CD', 'PD_CD', 'LAW_CAT_CD', 'ARREST_BORO', 'ARREST_PRECINCT'], axis = 1)
# Out:
#        ARREST_DATE                         PD_DESC  \
# 0       12/18/2021                          RAPE 1
# 1       11/25/2021                     ARSON 2,3,4
# 2       10/14/2021                     OBSCENITY 1
# 3       10/11/2021                     ARSON 2,3,4
# 4        9/28/2021                             NaN
# ...            ...                             ...
# 155502   1/10/2021  ROBBERY,OPEN AREA UNCLASSIFIED
# 155503    2/3/2021        WEAPONS POSSESSION 1 & 2
# 155504   2/13/2021                       ASSAULT 3
# 155505    1/4/2021        WEAPONS POSSESSION 1 & 2
# 155506    2/6/2021              CRIMINAL MIS 2 & 3
#
#                              OFNS_DESC AGE_GROUP PERP_SEX  \
# 0                                 RAPE     18-24        M
# 1                                ARSON     25-44        M
# 2                           SEX CRIMES     25-44        M
# 3                                ARSON     18-24        M
# ...

# %%
 #Wanted to Identify Crime, Age groups, race for crimes commited.
df.groupby(['PD_DESC','ARREST_DATE','AGE_GROUP','PERP_RACE'])['PERP_SEX'].count()
# Out:
# PD_DESC                         ARREST_DATE  AGE_GROUP  PERP_RACE
# A.B.C.,FALSE PROOF OF AGE       10/13/2021   25-44      BLACK HISPANIC    1
#                                 10/14/2021   25-44      BLACK             1
# ACCOSTING,FRAUDULENT            1/9/2021     45-64      BLACK             1
#                                                         WHITE             1
#                                 10/14/2021   65+        WHITE             1
#                                                                          ..
# WEAPONS,MFR,TRANSPORT,ETC.      7/30/2021    45-64      BLACK             1
#                                 8/2/2021     25-44      BLACK             1
#                                 8/30/2021    25-44      BLACK             1
# WEAPONS,PROHIBITED USE IMITATI  8/29/2021    25-44      BLACK             1
# WOUNDS,REPORTING OF             11/18/2021   25-44      BLACK             1
# Name: PERP_SEX, Length: 78557, dtype: int64

# %%
import seaborn as SNS
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

y = np.array([35,25,20,15,5])
mylabels = ['ARREST_DATE 35%','AGE_GROUP 25%','PERP_SEX 20%','PERP_RACE 15%','PD_DESC 5%']
myexplode = [0,0.2,0,0,0.1]

plt.pie(y,labels = mylabels, explode = myexplode, shadow = True)

plt.legend(title= "The Four Boros, SI_Irrelevant")
plt.show()
